# %%
# Import packages
from google.colab import drive
import pandas as pd
import csv
import json

# %%
#Connect with DRIVE env
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Function to change format to float
def type_to_float(df,float_variables):
  for var in float_variables:
    # Assuming 'column_name' is the column containing numbers with commas instead of dots
    df[var] = df[var].str.replace(',', '.')
    # Convert the column to numeric if necessary
    df[var] = pd.to_numeric(df[var])

# Define variables to change to float
float_variables = ['ecmaxcontribution', 'totalcost']

# Function to replace nas to zeros
def nas_to_zero(df,replace_variables):
  df[replace_variables] = df[replace_variables].fillna(0)

# %% [markdown]
# ## FP7

# %%
#Load the publications from the FP7 call
FP7_publications = pd.read_csv('/content/drive/MyDrive/data/RawCORDISdata/FP7_publications.csv', sep=';')

# %%
#Load projects from FP7 call
FP7_projects = pd.read_csv('/content/drive/MyDrive/data/RawCORDISdata/FP7_projects.csv', sep=';')

# %%
#To avoid conflict user lowercase and rename columns
FP7_projects.columns = FP7_projects.columns.str.lower()
FP7_projects = FP7_projects.rename(columns={'id':'project_id', 'title':'title_projects', 'contentupdatedate':'contentupdatedate_projects'})
# Convert variables to float
type_to_float(FP7_projects,float_variables)

# %%
#To avoid conflict user lowercase and rename columns
FP7_publications.columns = FP7_publications.columns.str.lower()
FP7_publications = FP7_publications.rename(columns={'title':'title_publications', 'author':'authors'})

# %%
#Merge each publication to the correct project
FP7_merged = pd.merge(FP7_projects, FP7_publications, on="project_id", how='outer', indicator=True)

# %%
#Delete the columns that are not present in the datasets for other calls
del_columns = ['qa_processed_doi', 'publication_type', 'pages', 'publisher','grantdoi', 'volume', 'record_id', 'repository_url','rcn']
for col in del_columns:
    del FP7_merged[col]

#Create columns:
#Correct "call"
FP7_merged['funding_body'] = 'FP7'
#Unknown values but relevant column in other datasets
FP7_merged['publication_date'] = 'unknown'
FP7_merged['projectacronym'] = 'unknown'

# %%
#Test that the df is correct and the columns are the correct type
display(FP7_merged.head())
FP7_merged.info()
# Out:
#    project_id acronym status                                title_projects  \
# 0      336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 1      336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 2      336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 3      336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 4      336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
#
#     startdate     enddate  totalcost  ecmaxcontribution     legalbasis  \
# 0  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 1  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 2  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 3  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 4  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
#
#        topics  ...                                          objective  \
# 0  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 1  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 2  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 3  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 4  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
#
#   contentupdatedate_projects  \
# 0        2016-12-19 10:56:33
# 1        2016-12-19 10:56:33
# 2        2016-12-19 10:56:33
# 3        2016-12-19 10:56:33
# 4        2016-12-19 10:56:33
#
#                                   title_publications  \
# 0  Membrane-Assisted Growth of DNA Origami Nanost...
# 1  Alignment and Graphene-Assisted Decoration of ...
# 2  DNA-Assembled Nanoparticle Rings Exhibit Elect...
# 3    Cellular Uptake of Tile-Assembled DNA Nanotubes
# 4  Molecular force spectroscopy with a DNA origam...
#
#                                              authors                      doi  \
# 0  Samet Kocabey , Susanne Kempter , Jonathan Lis...  10.1021/acsnano.5b00161
# 1  Kevin Martens , Timon Funck , Susanne Kempter ...   10.1002/smll.201503382
# 2  Eva-Maria Roller , Larousse Khosravi Khorashad...        10.1021/nl5046473
# 3  Samet Kocabey 1, Hanna Meinl 2, Iain S. MacPhe...      10.3390/nano5010047
# 4  Philipp C. Nickels , Bettina Wünsch , Phil Hol...  10.1126/science.aah5974
#
#    journal_title _merge funding_body publication_date projectacronym
# 0       ACS Nano   both          FP7          unknown        unknown
# 1          Small   both          FP7          unknown        unknown
# 2   Nano Letters   both          FP7          unknown        unknown
# 3  Nanomaterials   both          FP7          unknown        unknown
# 4        Science   both          FP7          unknown        unknown
#
# [5 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315780 entries, 0 to 315779
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   project_id                  315780 non-null  int64
#  1   acronym                     315713 non-null  object
#  2   status                      315702 non-null  object
#  3   title_projects              315713 non-null  object
#  4   startdate                   315591 non-null  object
#  5   enddate                     315591 non-null  object
#  6   totalcost                   315713 non-null  float64
#  7   ecmaxcontribution           315713 non-null  float64
#  8   legalbasis                  315713 non-null  object
#  9   topics                      315709 non-null  object
#  10  ecsignaturedate             0 non-null       float64
#  11  frameworkprogramme          315713 non-null  object
#  12  mastercall                  0 non-null       float64
#  13  subcall                     315713 non-null  object
#  14  fundingscheme               315713 non-null  object
#  15  nature                      2310 non-null    object
#  16  objective                   315705 non-null  object
#  17  contentupdatedate_projects  315713 non-null  object
#  18  title_publications          305149 non-null  object
#  19  authors                     303367 non-null  object
#  20  doi                         216684 non-null  object
#  21  journal_title               298941 non-null  object
#  22  _merge                      315780 non-null  category
#  23  funding_body                315780 non-null  object
#  24  publication_date            315780 non-null  object
#  25  projectacronym              315780 non-null  object
# dtypes: category(1), float64(4), int64(1), object(20)
# memory usage: 62.9+ MB

# %% [markdown]
# ## Horizon 2020

# %%
# Load the publications from Horizon 2020
H2020_publications = pd.read_csv('/content/drive/MyDrive/data/RawCORDISdata/Horizon2020_publications.csv', sep=';')

# %%
# Load the projects file from Horizon 2020
H2020_projects = pd.read_csv('/content/drive/MyDrive/data/RawCORDISdata/Horizon2020_projects.csv', sep=';')

# %%
# Reorganize projects file from Horizon 2020
H2020_projects.columns = H2020_projects.columns.str.lower()
H2020_projects = H2020_projects.rename(columns={'id':'project_id', 'title':'title_projects', 'contentupdatedate':'contentupdatedate_projects'})
H2020_projects['project_id'] = H2020_projects['project_id'].astype('object')

type_to_float(H2020_projects,float_variables)
del H2020_projects['rcn']

# %%
# Reorganize publications file from Horizon 2020
H2020_publications.columns = H2020_publications.columns.str.lower()
H2020_publications = H2020_publications.rename(columns={'projectid':'project_id', 'title':'title_publications','id':'project_id_full', 'journaltitle':'journal_title', 'publishedyear':'publication_date'})
del H2020_publications['contentupdatedate']
del H2020_publications['rcn']
H2020_publications['project_id'] = H2020_publications['project_id'].astype('object')

# %%
#Merge projects and publications
H2020_merged = pd.merge(H2020_projects, H2020_publications, on="project_id", how='outer', indicator=True)

#Delete the columns that we deemed unnecessary
colums_del_2020 = ['isbn', 'issn', 'journalnumber', 'project_id_full', 'publishedpages', 'ispublishedas', 'collection', 'grantdoi']
for col in colums_del_2020:
    del H2020_merged[col]

#H2020_merged = H2020_merged.rename(columns={'grantdoi':'doi'})
H2020_merged['funding_body'] = 'H2020'

# %%
#Test that the merged df is correct and the columns are the correct type
display(H2020_merged.head())
H2020_merged.info()
# Out:
#   project_id    acronym  status  \
# 0     810630  VALORTECH  SIGNED
# 1     810630  VALORTECH  SIGNED
# 2     810630  VALORTECH  SIGNED
# 3     810630  VALORTECH  SIGNED
# 4     810630  VALORTECH  SIGNED
#
#                                       title_projects   startdate     enddate  \
# 0  ERA Chair for Food (By-) Products Valorisation...  2018-07-01  2023-12-31
# 1  ERA Chair for Food (By-) Products Valorisation...  2018-07-01  2023-12-31
# 2  ERA Chair for Food (By-) Products Valorisation...  2018-07-01  2023-12-31
# 3  ERA Chair for Food (By-) Products Valorisation...  2018-07-01  2023-12-31
# 4  ERA Chair for Food (By-) Products Valorisation...  2018-07-01  2023-12-31
#
#    totalcost  ecmaxcontribution     legalbasis              topics  ...  \
# 0  2498625.0          2498625.0  H2020-EU.4.c.  WIDESPREAD-03-2017  ...
# 1  2498625.0          2498625.0  H2020-EU.4.c.  WIDESPREAD-03-2017  ...
# 2  2498625.0          2498625.0  H2020-EU.4.c.  WIDESPREAD-03-2017  ...
# 3  2498625.0          2498625.0  H2020-EU.4.c.  WIDESPREAD-03-2017  ...
# 4  2498625.0          2498625.0  H2020-EU.4.c.  WIDESPREAD-03-2017  ...
#
#                                            objective  \
# 0  Advanced food processing technologies, minimum...
# 1  Advanced food processing technologies, minimum...
# 2  Advanced food processing technologies, minimum...
# 3  Advanced food processing technologies, minimum...
# 4  Advanced food processing technologies, minimum...
#
#   contentupdatedate_projects  \
# 0        2023-05-13 18:49:37
# 1        2023-05-13 18:49:37
# 2        2023-05-13 18:49:37
# 3        2023-05-13 18:49:37
# 4        2023-05-13 18:49:37
#
#                                   title_publications  \
# 0  Comparison of chemical composition of Hypericu...
# 1  Changes in rheological properties of Edam-type...
# 2  Fractionation of sea buckthorn pomace and seed...
# 3  Effect of post-harvest flame-defoliation on st...
# 4  Phytochemical characterization and antimicrobi...
#
#                                              authors  \
# 0  Rusalepp, Linda; Raal, Ain; Püssa, Tõnu; Mäeor...
# 1  Henno, Merike; Jõudu, Ivi; Kaart, Tanel; Veski...
# 2  V. Kitrytė, D. Povilaitis, V. Kraujalienė, V. ...
# 3    Reelika RÄTSEP, Ulvi MOOR, Ele VOOL, Kadri KARP
# 4  Radenkovs, Vitalijs; Püssa, Tõnu; Juhnevica-Ra...
#
#                          journal_title publication_date  \
# 0  Biochemical Systematics and Ecology           2017.0
# 1        Agricultural and Food Science           2017.0
# 2    LWT – Food Science and Technology           2017.0
# 3              Zemdirbyste-Agriculture           2015.0
# 4                      Food Bioscience           2018.0
#
#                           doi projectacronym _merge funding_body
# 0   10.1016/j.bse.2017.06.004      VALORTECH   both        H2020
# 1        10.23986/afsci.63132      VALORTECH   both        H2020
# 2   10.1016/j.lwt.2017.02.041      VALORTECH   both        H2020
# 3   10.13080/z-a.2015.102.051      VALORTECH   both        H2020
# 4  10.1016/j.fbio.2018.05.010      VALORTECH   both        H2020
#
# [5 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381255 entries, 0 to 381254
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   project_id                  381255 non-null  object
#  1   acronym                     381255 non-null  object
#  2   status                      381255 non-null  object
#  3   title_projects              381255 non-null  object
#  4   startdate                   381244 non-null  object
#  5   enddate                     381244 non-null  object
#  6   totalcost                   381255 non-null  float64
#  7   ecmaxcontribution           381255 non-null  float64
#  8   legalbasis                  377220 non-null  object
#  9   topics                      381255 non-null  object
#  10  ecsignaturedate             381255 non-null  object
#  11  frameworkprogramme          381255 non-null  object
#  12  mastercall                  381255 non-null  object
#  13  subcall                     381255 non-null  object
#  14  fundingscheme               381240 non-null  object
#  15  nature                      14986 non-null   object
#  16  objective                   381255 non-null  object
#  17  contentupdatedate_projects  381255 non-null  object
#  18  title_publications          368009 non-null  object
#  19  authors                     367998 non-null  object
#  20  journal_title               340461 non-null  object
#  21  publication_date            367955 non-null  float64
#  22  doi                         293787 non-null  object
#  23  projectacronym              368010 non-null  object
#  24  _merge                      381255 non-null  category
#  25  funding_body                381255 non-null  object
# dtypes: category(1), float64(3), object(22)
# memory usage: 76.0+ MB

# %% [markdown]
# ## Horizon E

# %%
#Load the Horizon Europe projects file
HE_projects = pd.read_csv('/content/drive/MyDrive/data/RawCORDISdata/HorizonE_projects.csv', sep=';')

# %%
#Transform columns to lowercase to avoid errors
HE_projects.columns = HE_projects.columns.str.lower()

#Rename the columns to match the previous dataframes
HE_projects = HE_projects.rename(columns={'id':'project_id', 'title':'title_projects', 'contentupdatedate':'contentupdatedate_projects'})

#Delete and modify the necessary columns
del HE_projects['rcn']
type_to_float(HE_projects,float_variables)

# %%
#Load the Horizon Europe publications file file
HE_publications = pd.read_csv('/content/drive/MyDrive/data/RawCORDISdata/HorizonE_publications.csv', sep=';')

# %%
#Transform columns to lowercase to avoid errors
HE_publications.columns = HE_publications.columns.str.lower()

#Rename the columns to match the previous dataframes
HE_publications = HE_publications.rename(columns={'projectid':'project_id', 'title':'title_publications','id':'project_id_full','journaltitle':'journal_title', 'publishedyear':'publication_date'})

#Delete and modify the necessary columns
del HE_publications['contentupdatedate']
del HE_publications['rcn']
HE_publications.columns = HE_publications.columns.astype('object')

# %%
#Merge the project and publications dfs
HE_merged = pd.merge(HE_projects, HE_publications, on="project_id", how='outer', indicator=True)
HE_merged['funding_body'] = 'HE'

#Delete the unnecesary columns
colums_del = ['isbn', 'issn', 'journalnumber', 'project_id_full', 'publishedpages', 'ispublishedas', 'collection', 'grantdoi']
for col in colums_del:
    del HE_merged[col]

# %%
# To check match columns - but code no needed
different_columns = []

# Columns in df1 but not in df2
for col in H2020_merged.columns:
    if col not in FP7_merged.columns:
        different_columns.append(col)

# Columns in df2 but not in df1
for col in FP7_merged.columns:
    if col not in H2020_merged.columns:
        different_columns.append(col)

different_columns = list(set(different_columns))  # Remove duplicates

print("Different column names:")
print(different_columns)
# Out:
# Different column names:
# []

# %%
# Merge cordis data - from the 3 frameworks
cordis_projects_publications = pd.concat([FP7_merged, H2020_merged, HE_merged], ignore_index=True)

# %%
#Print to verify the shape of the merged dfs and verify the number of columns
print(FP7_merged.shape)
print(H2020_merged.shape)
print(HE_merged.shape)

print('The full merged df should be', len(FP7_merged)+len(H2020_merged)+len(HE_merged),' entries long')
# Out:
# (315780, 26)
# (381255, 26)
# (9796, 26)
# The full merged df should be 706831  entries long

# %%
display(cordis_projects_publications.head())
print(cordis_projects_publications.shape)
# Out:
#   project_id acronym status                                title_projects  \
# 0     336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 1     336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 2     336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 3     336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
# 4     336440    ORCA    CLO  Optical Responses Controlled by DNA Assembly
#
#     startdate     enddate  totalcost  ecmaxcontribution     legalbasis  \
# 0  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 1  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 2  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 3  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
# 4  2013-12-01  2018-11-30  1433840.0          1433840.0  FP7-IDEAS-ERC
#
#        topics  ...                                          objective  \
# 0  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 1  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 2  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 3  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
# 4  ERC-SG-PE5  ...  Artificially constructed materials can be desi...
#
#   contentupdatedate_projects  \
# 0        2016-12-19 10:56:33
# 1        2016-12-19 10:56:33
# 2        2016-12-19 10:56:33
# 3        2016-12-19 10:56:33
# 4        2016-12-19 10:56:33
#
#                                   title_publications  \
# 0  Membrane-Assisted Growth of DNA Origami Nanost...
# 1  Alignment and Graphene-Assisted Decoration of ...
# 2  DNA-Assembled Nanoparticle Rings Exhibit Elect...
# 3    Cellular Uptake of Tile-Assembled DNA Nanotubes
# 4  Molecular force spectroscopy with a DNA origam...
#
#                                              authors                      doi  \
# 0  Samet Kocabey , Susanne Kempter , Jonathan Lis...  10.1021/acsnano.5b00161
# 1  Kevin Martens , Timon Funck , Susanne Kempter ...   10.1002/smll.201503382
# 2  Eva-Maria Roller , Larousse Khosravi Khorashad...        10.1021/nl5046473
# 3  Samet Kocabey 1, Hanna Meinl 2, Iain S. MacPhe...      10.3390/nano5010047
# 4  Philipp C. Nickels , Bettina Wünsch , Phil Hol...  10.1126/science.aah5974
#
#    journal_title _merge funding_body publication_date projectacronym
# 0       ACS Nano   both          FP7          unknown        unknown
# 1          Small   both          FP7          unknown        unknown
# 2   Nano Letters   both          FP7          unknown        unknown
# 3  Nanomaterials   both          FP7          unknown        unknown
# 4        Science   both          FP7          unknown        unknown
#
# [5 rows x 26 columns]
# (706831, 26)

# %%
cordis_projects_publications.to_csv('/content/drive/MyDrive/data/cordis_projects_publications.csv', sep=';')

# %% [markdown]
# # COUNTS DATA

# %%
#Set the path to the counts data file
counts_data = "/content/drive/MyDrive/data/results_for_analysis.json"

# %%
# Load json function
def load_json(file_path):
    with open(file_path) as json_file:
        return json.load(json_file)

#Load the file and turn into df
loadedfile = load_json(counts_data)
counts_data_csv = pd.DataFrame(loadedfile)

# %%
display(counts_data_csv)
# Out:
#              pmcid    agg_sentence_index  \
# 0       PMC9683380       [3, 5, 6, 7, 8]
# 1       PMC5137654             [1, 3, 4]
# 2       PMC7906844                   [1]
# 3       PMC3387267                  [12]
# 4       PMC4221596                  [28]
# ...            ...                   ...
# 166006  PMC5432274          [0, 2, 3, 4]
# 166007  PMC6317672                [0, 1]
# 166008  PMC3155515                  [28]
# 166009    PMC61449              [13, 31]
# 166010  PMC6883407  [1, 3, 6, 7, 36, 37]
#
#                                        agg_n_fem  \
# 0            [null, null, "\"352\"", null, null]
# 1                         ["\"30\"", null, null]
# 2                                         [null]
# 3                                         [null]
# 4                                         [null]
# ...                                          ...
# 166006              [null, null, "\"99\"", null]
# 166007                              [null, null]
# 166008                                    [null]
# 166009                              [null, null]
# 166010  [null, null, "\"43\"", null, null, null]
#
#                                       agg_n_male  \
# 0            [null, null, "\"328\"", null, null]
# 1                         ["\"30\"", null, null]
# 2                                         [null]
# 3                                         [null]
# 4                                         [null]
# ...                                          ...
# 166006             [null, null, "\"181\"", null]
# 166007                              [null, null]
# 166008                                    [null]
# 166009                              [null, null]
# 166010  [null, null, "\"23\"", null, null, null]
#
#                                 agg_perc_fem  \
# 0             [null, null, null, null, null]
# 1                         [null, null, null]
# 2                                     [null]
# 3                                     [null]
# 4                                     [null]
# ...                                      ...
# 166006              [null, null, null, null]
# 166007                          [null, null]
# 166008                                [null]
# 166009                          [null, null]
# 166010  [null, null, null, null, null, null]
#
#                                agg_perc_male  \
# 0             [null, null, null, null, null]
# 1                         [null, null, null]
# 2                                     [null]
# 3                                     [null]
# 4                                     [null]
# ...                                      ...
# 166006              [null, null, null, null]
# 166007                          [null, null]
# 166008                                [null]
# 166009                          [null, null]
# 166010  [null, null, null, null, null, null]
#
#                                                agg_sample clean_n_fem  \
# 0       ["\"##3\"", "\"##3\"", "\"70\"", "\"##6\"", "\...       [352]
# 1                          ["\"60\"", "\"16\"", "\"46\""]        [30]
# 2                                          ["\"thirty\""]          []
# 3                                              ["\"12\""]          []
# 4                                              ["\"90\""]          []
# ...                                                   ...         ...
# 166006             ["\"280\"", "\"280\"", null, "\"48\""]        [99]
# 166007                              ["\"20\"", "\"six\""]          []
# 166008                                         ["\"76\""]          []
# 166009                           ["\"five\"", "\"five\""]          []
# 166010  ["\"43\"", "\"69\"", "\"66\"", "\"34\"", "\"35...        [43]
#
#        clean_n_male clean_perc_fem  ...  \
# 0             [328]             []  ...
# 1              [30]             []  ...
# 2                []             []  ...
# 3                []             []  ...
# 4                []             []  ...
# ...             ...            ...  ...
# 166006        [181]             []  ...
# 166007           []             []  ...
# 166008           []             []  ...
# 166009           []             []  ...
# 166010         [23]             []  ...
#
#                                  article_categories  \
# 0                                 ["Endocrinology"]
# 1                                         ["Spine"]
# 2                              ["Research Article"]
# 3       ["Research Article", "Biology", "Medicine"]
# 4                              ["Original Article"]
# ...                                             ...
# 166006                           ["Research Paper"]
# 166007                                 ["Articles"]
# 166008              ["Research Article", "Biology"]
# 166009                         ["Research Article"]
# 166010                                 ["Oncology"]
#
#                                             article_title  \
# 0       Differential diagnostic value of plain CT scan...
# 1       Posterior hemivertebra resection and monosegme...
# 2       Can silver diamine fluoride or silver nanopart...
# 3       NOTCH1 Signaling Promotes Human T-Cell Acute L...
# 4       A Cancer Cell-Activatable Aptamer-Reporter Sys...
# ...                                                   ...
# 166006  Expression and functional regulation of stemne...
# 166007  Role of the long non-coding RNA-Annexin A2 pse...
# 166008  Transcriptome Sequencing of the Blind Subterra...
# 166009  Absence of rapid selection for acyclovir or pe...
# 166010  Expression and Clinical Implications of Cystei...
#
#                                                   authors  \
# 0       ["Zhijiang Han", "Mengwei Wu", "Peiying Wei", ...
# 1       ["X Zhu", "X Wei", "J Chen", "C Li", "M Li", "...
# 2       ["Jaqueline Costa Favaro", "Yana Cosendey Tole...
# 3       ["Wenxue Ma", "Alejandro Gutierrez", "Daniel J...
# 4          ["Zihua Zeng", "Ching-Hsuan Tung", "Youli Zu"]
# ...                                                   ...
# 166006  ["Zhuan Lv", "Jane J. Yu", "Wei-Jie Zhang", "L...
# 166007  ["Yeletai Nuerzhati", "Rui Dong", "Zai Song", ...
# 166008  ["Assaf Malik", "Abraham Korol", "Sariel H\u00...
# 166009  ["Robert T Sarisky", "H Ron Bartus", "Shelley ...
# 166010  ["Siddharth Mehra", "Rajesh Panwar", "Bhaskar ...
#
#                                            copyright_info  \
# 0       Copyright © 2022 Han, Wu, Wei, Zhu, Zhang, Din...
# 1              Copyright © 2013 Royal College of Surgeons
# 2       Copyright © 2021. The Korean Academy of Conser...
# 3                                               Ma et al.
# 4       Copyright © 2014 American Society of Gene & Ce...
# ...                                                   ...
# 166006                        Copyright: © 2017 Lv et al.
# 166007                      Copyright: © Nuerzhati et al.
# 166008                                       Malik et al.
# 166009  Copyright © 2001 Sarisky et al; licensee BioMe...
# 166010  Copyright © 2019 Mehra, Panwar, Thakur, Yadav,...
#
#                                                   funding     publisher_id  \
# 0                                                      []             None
# 1                                                      []           650173
# 2       [{"institution": "Coordena\u00e7\u00e3o de Ape...       2021460211
# 3                                                      []  PONE-D-12-13887
# 4                                                      []             None
# ...                                                   ...              ...
# 166006                                                 []            15624
# 166007                                                 []  ijmm-43-02-0739
# 166008                                                 []  PONE-D-11-07297
# 166009                                                 []   1471-2334-1-24
# 166010                                                 []             None
#
#                                      doi  \
# 0             10.3389/fendo.2022.1007870
# 1       10.1308/003588414X13824511650173
# 2                 10.5395/rde.2021.46.e7
# 3           10.1371/journal.pone.0039725
# 4                   10.1038/mtna.2014.36
# ...                                  ...
# 166006         10.18632/oncotarget.15624
# 166007            10.3892/ijmm.2018.4023
# 166008      10.1371/journal.pone.0021227
# 166009            10.1186/1471-2334-1-24
# 166010           10.3389/fonc.2019.01239
#
#                                             journal_title  \
# 0                              Frontiers in Endocrinology
# 1       Annals of The Royal College of Surgeons of Eng...
# 2                     Restorative Dentistry & Endodontics
# 3                                                PLoS ONE
# 4                        Molecular Therapy. Nucleic Acids
# ...                                                   ...
# 166006                                         Oncotarget
# 166007        International Journal of Molecular Medicine
# 166008                                           PLoS ONE
# 166009                            BMC Infectious Diseases
# 166010                              Frontiers in Oncology
#
#                                                  keywords     publication_date
# 0       ["adrenal gland neoplasms", "adrenal adenoma",...  2022-11-09 00:00:00
# 1       ["Hemivertebra resection", "Monosegmental fusi...                 None
# 2       ["Cariostatic agents", "Dental caries", "Nanop...                 None
# 3                                                      []                 None
# 4       ["aptamer-reporter", "cell-activatable", "circ...                 None
# ...                                                   ...                  ...
# 166006  ["Lgr5", "esophageal squamous cell carcinoma",...  2017-04-18 00:00:00
# 166007  ["Annexin A2 pseudogene 3", "Annexin A2", "bil...                 None
# 166008                                                 []                 None
# 166009                                                 []                 None
# 166010  ["gallbladder carcinoma", "cathepsin L", "cath...  2019-11-22 00:00:00
#
# [166011 rows x 27 columns]

# %%
#Transform to csv to merge
counts_data_csv.to_csv('counts_data.csv')
counts_data_csv.columns
# Out:
# Index(['pmcid', 'agg_sentence_index', 'agg_n_fem', 'agg_n_male',
#        'agg_perc_fem', 'agg_perc_male', 'agg_sample', 'clean_n_fem',
#        'clean_n_male', 'clean_perc_fem', 'clean_perc_male', 'clean_sample',
#        'max_n_fem', 'max_n_male', 'max_perc_fem', 'max_perc_male',
#        'max_sample', 'article_categories', 'article_title', 'authors',
#        'copyright_info', 'funding', 'publisher_id', 'doi', 'journal_title',
#        'keywords', 'publication_date'],
#       dtype='object')

# %%
#Create the list of DOIs to filter the merged dataframe and only keep data that matches with the counts_data
list_doi = counts_data_csv['doi'].tolist()

# %%
# Subset cordis
cordis_subset = cordis_projects_publications[cordis_projects_publications['doi'].isin(list_doi)]

# Change names
cordis_subset = cordis_subset.rename(columns={'acronym':'acronym_projects', 'projectacronym':'acronym_publications'})

# Specify the suffix to add
suffix_cordis = '_cordis'

# Add the suffix to all columns except for 'funding_body'
for column in cordis_subset.columns:
    if column != 'funding_body' and column != 'doi':
        cordis_subset.rename(columns={column: f"{column}{suffix_cordis}"}, inplace=True)

# Display the subset DataFrame
display(cordis_subset.head())
# Out:
#        project_id_cordis acronym_projects_cordis status_cordis  \
# 41                281666     RC3H1/2-SPECIFICITY           CLO
# 537               322605             META-GROWTH           CLO
# 574               322605             META-GROWTH           CLO
# 578               322605             META-GROWTH           CLO
# 1007              261349                  UNITAS           CLO
# ...                  ...                     ...           ...
# 695853         101016834               HosmartAI        SIGNED
# 696278            826404                   CUREX        CLOSED
# 699495         101046846                MAPWORMS        SIGNED
# 701225         101046041                 CoVICIS        SIGNED
# 702787         101039672                   TEMPO        SIGNED
#
#                                     title_projects_cordis startdate_cordis  \
# 41      Specificity of Rc3h1/2 proteins in post-transc...       2011-11-01
# 537     Metabolic regulation of growth and body compos...       2013-10-01
# 574     Metabolic regulation of growth and body compos...       2013-10-01
# 578     Metabolic regulation of growth and body compos...       2013-10-01
# 1007    Universal coverage in Tanzania and South Afric...       2011-01-01
# ...                                                   ...              ...
# 695853             Hospital Smart development based on AI       2021-01-01
# 696278            seCUre and pRivate hEalth data eXchange       2018-12-01
# 699495       Mimicking Adaptation and Plasticity in WORMS       2022-05-01
# 701225  EU-Africa Concerted Action on SAR-CoV-2 Virus ...       2021-11-01
# 702787  Solving the 'time puzzle' of epigenetic effect...       2022-06-01
#
#        enddate_cordis  totalcost_cordis  ecmaxcontribution_cordis  \
# 41         2016-10-31        1392400.00                 1392400.0
# 537        2018-09-30        2491200.00                 2491200.0
# 574        2018-09-30        2491200.00                 2491200.0
# 578        2018-09-30        2491200.00                 2491200.0
# 1007       2016-03-31        3935289.12                 3000000.0
# ...               ...               ...                       ...
# 695853     2024-05-31       11898695.00                 9997244.0
# 696278     2022-03-31        4987825.00                 4987825.0
# 699495     2026-04-30        2896750.00                 2896750.0
# 701225     2024-10-31       10048971.68                10048971.0
# 702787     2027-05-31        1500000.00                 1500000.0
#
#        legalbasis_cordis                          topics_cordis  ...  \
# 41         FP7-IDEAS-ERC                             ERC-SG-LS6  ...
# 537        FP7-IDEAS-ERC                             ERC-AG-LS7  ...
# 574        FP7-IDEAS-ERC                             ERC-AG-LS7  ...
# 578        FP7-IDEAS-ERC                             ERC-AG-LS7  ...
# 1007          FP7-HEALTH                      HEALTH.2010.3.4-7  ...
# ...                  ...                                    ...  ...
# 695853   H2020-EU.2.1.1.                         DT-ICT-12-2020  ...
# 696278     H2020-EU.3.1.                         SU-TDS-02-2018  ...
# 699495       HORIZON.3.1  HORIZON-EIC-2021-PATHFINDEROPEN-01-01  ...
# 701225       HORIZON.2.1         HORIZON-HLTH-2021-CORONA-01-02  ...
# 702787       HORIZON.1.1                           ERC-2021-STG  ...
#
#                                          objective_cordis  \
# 41      We are constantly protected by our adaptive im...
# 537     Nutrient exposure during pregnancy and childho...
# 574     Nutrient exposure during pregnancy and childho...
# 578     Nutrient exposure during pregnancy and childho...
# 1007    The goal of universal health coverage is recei...
# ...                                                   ...
# 695853  "HosmartAI will create a common open Integrati...
# 696278  The Health sector’s increasing dependence on d...
# 699495  Traditionally, a robot is a machine controlled...
# 701225  Despite of the successful advances achieved to...
# 702787  TEMPO aims to solve the newly discovered epige...
#
#        contentupdatedate_projects_cordis  \
# 41                   2016-10-31 08:36:51
# 537                  2022-02-10 20:18:14
# 574                  2022-02-10 20:18:14
# 578                  2022-02-10 20:18:14
# 1007                 2017-10-06 09:16:08
# ...                                  ...
# 695853               2023-03-21 17:21:39
# 696278               2023-03-10 22:28:52
# 699495               2022-08-24 00:12:04
# 701225               2022-07-13 16:26:14
# 702787               2022-07-22 19:28:39
#
#                                 title_publications_cordis  \
# 41      Roquin binds microRNA-146a and Argonaute2 to r...
# 537     The association of fatty acid desaturase gene ...
# 574     Sex differences in the association of phosphol...
# 578     Maternal Pre-Pregnancy Obesity Is Associated w...
# 1007    Whole-system change: case study of factors fac...
# ...                                                   ...
# 695853  Study protocol: a survey exploring patients’ a...
# 696278  Influence of Human Factors on Cyber Security w...
# 699495    A Bioinspired Fluid-Filled Soft Linear Actuator
# 701225  Longitudinal evaluation of the impact of immun...
# 702787  The gut microbiome and child mental health: A ...
#
#                                            authors_cordis  \
# 41      Monika Srivastava , Guowen Duan , Nadia J. Ker...
# 537     Conny Tanjung , Peter Rzehak , Herawati Sudoyo...
# 574     Sebastian Rauschert , Olaf Uhl , Berthold Kole...
# 578     Signe Altmäe , Maria Teresa Segura , Francisco...
# 1007    Helen Schneider , Rene English , Hanani Tabana...
# ...                                                   ...
# 695853  Izidor Mlakar; Tadej Kampič; Vojko Flis; Nina ...
# 696278  Sokratis Nifakos; Krishna Chandramouli; Charou...
# 699495  Filogna, Silvia; Paterno, Linda; Vecchi, Fabri...
# 701225                                                DOI
# 702787  Kraaij R, Schuurmans IK, Radjabzadeh D, Tiemei...
#
#                                  doi                    journal_title_cordis  \
# 41                10.1038/ncomms7253                   Nature Communications
# 537              10.1093/ajcn/nqy166  American Journal of Clinical Nutrition
# 574        10.1186/s13293-017-0131-0              Biology of Sex Differences
# 578     10.1371/journal.pone.0169223                                PLoS One
# 1007       10.1186/s12913-014-0609-y            BMC Health Services Research
# ...                              ...                                     ...
# 695853   10.1136/bmjopen-2021-054310                                BMJ Open
# 696278             10.3390/s21155119                                 Sensors
# 699495        10.1089/soro.2021.0091                           Soft Robotics
# 701225      10.3389/fmed.2022.978764                    Front Med (Lausanne)
# 702787     10.1016/j.bbi.2022.12.006           Brain, Behavior, and Immunity
#
#        _merge_cordis funding_body publication_date_cordis  \
# 41              both          FP7                 unknown
# 537             both          FP7                 unknown
# 574             both          FP7                 unknown
# 578             both          FP7                 unknown
# 1007            both          FP7                 unknown
# ...              ...          ...                     ...
# 695853          both        H2020                  2022.0
# 696278          both        H2020                  2021.0
# 699495          both           HE                  2022.0
# 701225          both           HE                  2022.0
# 702787          both           HE                  2022.0
#
#        acronym_publications_cordis
# 41                         unknown
# 537                        unknown
# 574                        unknown
# 578                        unknown
# 1007                       unknown
# ...                            ...
# 695853                   HosmartAI
# 696278                       CUREX
# 699495                    MAPWORMS
# 701225                     CoVICIS
# 702787                       TEMPO
#
# [3436 rows x 26 columns]

# %%
#Check that all columns are correct and check data types
cordis_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3436 entries, 41 to 702787
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   project_id_cordis                  3436 non-null   object
#  1   acronym_projects_cordis            3435 non-null   object
#  2   status_cordis                      3435 non-null   object
#  3   title_projects_cordis              3435 non-null   object
#  4   startdate_cordis                   3435 non-null   object
#  5   enddate_cordis                     3435 non-null   object
#  6   totalcost_cordis                   3435 non-null   float64
#  7   ecmaxcontribution_cordis           3435 non-null   float64
#  8   legalbasis_cordis                  3395 non-null   object
#  9   topics_cordis                      3435 non-null   object
#  10  ecsignaturedate_cordis             1731 non-null   object
#  11  frameworkprogramme_cordis          3435 non-null   object
#  12  mastercall_cordis                  1731 non-null   object
#  13  subcall_cordis                     3435 non-null   object
#  14  fundingscheme_cordis               3435 non-null   object
#  15  nature_cordis                      213 non-null    object
#  16  objective_cordis                   3435 non-null   object
#  17  contentupdatedate_projects_cordis  3435 non-null   object
#  18  title_publications_cordis          3435 non-null   object
#  19  authors_cordis                     3427 non-null   object
#  20  doi                                3436 non-null   object
#  21  journal_title_cordis               3434 non-null   object
#  22  _merge_cordis                      3436 non-null   category
#  23  funding_body                       3436 non-null   object
#  24  publication_date_cordis            3436 non-null   object
#  25  acronym_publications_cordis        3436 non-null   object
# dtypes: category(1), float64(2), object(23)
# memory usage: 701.4+ KB

# %%
#Merge the counts data with the recently created cordis subset
merged_data = pd.merge(counts_data_csv, cordis_subset, on="doi", how='inner')
merged_data
replace_variables = ['totalcost_cordis', 'ecmaxcontribution_cordis', 'clean_n_male', 'clean_n_fem', 'clean_perc_male', 'clean_perc_fem', 'max_n_male', 'max_n_fem', 'max_perc_male', 'max_perc_fem' ]

# Call function to replace zeros
nas_to_zero(merged_data,replace_variables)

# %%
#Visualize the merged dataframe
display(merged_data.head())
print(merged_data.info())
# Out:
#         pmcid     agg_sentence_index  \
# 0  PMC4242463  [1, 4, 6, 10, 13, 24]
# 1  PMC5512773                 [1, 3]
# 2  PMC5512773                 [1, 3]
# 3  PMC4492817                   [32]
# 4  PMC4492817                   [32]
#
#                                    agg_n_fem  \
# 0  [null, null, null, "\"##7\"", null, null]
# 1                               [null, null]
# 2                               [null, null]
# 3                                     [null]
# 4                                     [null]
#
#                              agg_n_male                          agg_perc_fem  \
# 0  [null, null, null, null, null, null]  [null, null, null, null, null, null]
# 1                          [null, null]                          [null, null]
# 2                          [null, null]                          [null, null]
# 3                                [null]                                [null]
# 4                                [null]                                [null]
#
#                           agg_perc_male  \
# 0  [null, null, null, null, null, null]
# 1                          [null, null]
# 2                          [null, null]
# 3                                [null]
# 4                                [null]
#
#                                           agg_sample clean_n_fem clean_n_male  \
# 0  ["\"36\"", "\"##7\"", "\"##4\"", "\"56\"", "\"...         [7]           []
# 1                        ["\"seven\"", "\"eleven\""]          []           []
# 2                        ["\"seven\"", "\"eleven\""]          []           []
# 3                                         ["\"14\""]          []           []
# 4                                         ["\"14\""]          []           []
#
#   clean_perc_fem  ... nature_cordis  \
# 0             []  ...           NaN
# 1             []  ...           NaN
# 2             []  ...           NaN
# 3             []  ...           NaN
# 4             []  ...           NaN
#
#                                     objective_cordis  \
# 0  "Genome-wide association studies of complex tr...
# 1  Next generation sequencing (NGS) is revolution...
# 2  Cytogenetic diagnostic approaches provide info...
# 3  Tetralogy of Fallot (TOF) is the most common c...
# 4  Tetralogy of Fallot (TOF) is the most common c...
#
#    contentupdatedate_projects_cordis  \
# 0                2015-03-10 19:10:33
# 1                2022-02-09 10:28:40
# 2                2022-08-15 14:25:56
# 3                2017-05-26 01:37:18
# 4                2017-05-26 01:37:18
#
#                            title_publications_cordis  \
# 0  Genetic characterization of Greek population i...
# 1  Single-molecule quantification of 5-hydroxymet...
# 2  Single-molecule quantification of 5-hydroxymet...
# 3  Antisense-mediated exon skipping: a therapeuti...
# 4  Antisense-mediated exon skipping: a therapeuti...
#
#                                       authors_cordis     journal_title_cordis  \
# 0  Panoutsopoulou, K., Hatzikotoulas, K., Xifara,...    Nature Communications
# 1  Noa Gilat , Tzlil Tabachnik , Amit Shwartz , T...     Clinical epigenetics
# 2  Noa Gilat, Tzlil Tabachnik, Amit Shwartz, Tama...     Clinical Epigenetics
# 3  M. Gramlich , L. S. Pane , Q. Zhou , Z. Chen ,...  EMBO Molecular Medicine
# 4  M. Gramlich , L. S. Pane , Q. Zhou , Z. Chen ,...  EMBO Molecular Medicine
#
#   _merge_cordis funding_body publication_date_cordis  \
# 0          both          FP7                 unknown
# 1          both          FP7                 unknown
# 2          both        H2020                  2017.0
# 3          both          FP7                 unknown
# 4          both          FP7                 unknown
#
#   acronym_publications_cordis
# 0                     unknown
# 1                     unknown
# 2                   BeyondSeq
# 3                     unknown
# 4                     unknown
#
# [5 rows x 52 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3436 entries, 0 to 3435
# Data columns (total 52 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   pmcid                              3436 non-null   object
#  1   agg_sentence_index                 3436 non-null   object
#  2   agg_n_fem                          3436 non-null   object
#  3   agg_n_male                         3436 non-null   object
#  4   agg_perc_fem                       3436 non-null   object
#  5   agg_perc_male                      3436 non-null   object
#  6   agg_sample                         3436 non-null   object
#  7   clean_n_fem                        3436 non-null   object
#  8   clean_n_male                       3436 non-null   object
#  9   clean_perc_fem                     3436 non-null   object
#  10  clean_perc_male                    3436 non-null   object
#  11  clean_sample                       3436 non-null   object
#  12  max_n_fem                          3436 non-null   int64
#  13  max_n_male                         3436 non-null   int64
#  14  max_perc_fem                       3436 non-null   int64
#  15  max_perc_male                      3436 non-null   int64
#  16  max_sample                         3238 non-null   object
#  17  article_categories                 3436 non-null   object
#  18  article_title                      3394 non-null   object
#  19  authors                            3436 non-null   object
#  20  copyright_info                     3054 non-null   object
#  21  funding                            3436 non-null   object
#  22  publisher_id                       2532 non-null   object
#  23  doi                                3436 non-null   object
#  24  journal_title                      3436 non-null   object
#  25  keywords                           3436 non-null   object
#  26  publication_date                   2316 non-null   object
#  27  project_id_cordis                  3436 non-null   object
#  28  acronym_projects_cordis            3435 non-null   object
#  29  status_cordis                      3435 non-null   object
#  30  title_projects_cordis              3435 non-null   object
#  31  startdate_cordis                   3435 non-null   object
#  32  enddate_cordis                     3435 non-null   object
#  33  totalcost_cordis                   3436 non-null   float64
#  34  ecmaxcontribution_cordis           3436 non-null   float64
#  35  legalbasis_cordis                  3395 non-null   object
#  36  topics_cordis                      3435 non-null   object
#  37  ecsignaturedate_cordis             1731 non-null   object
#  38  frameworkprogramme_cordis          3435 non-null   object
#  39  mastercall_cordis                  1731 non-null   object
#  40  subcall_cordis                     3435 non-null   object
#  41  fundingscheme_cordis               3435 non-null   object
#  42  nature_cordis                      213 non-null    object
#  43  objective_cordis                   3435 non-null   object
#  44  contentupdatedate_projects_cordis  3435 non-null   object
#  45  title_publications_cordis          3435 non-null   object
#  46  authors_cordis                     3427 non-null   object
#  47  journal_title_cordis               3434 non-null   object
#  48  _merge_cordis                      3436 non-null   category
#  49  funding_body                       3436 non-null   object
#  50  publication_date_cordis            3436 non-null   object
#  51  acronym_publications_cordis        3436 non-null   object
# dtypes: category(1), float64(2), int64(4), object(45)
# memory usage: 1.4+ MB
# None

# %%
#Save data to the correct file location
merged_data.to_csv('/content/drive/MyDrive/data/final_subset.csv',sep=';')

# %%
#Print the shape of the selected projects from each funding project's intersection with the counts.
filtered_fp7 = merged_data[merged_data['funding_body'] == 'FP7']
print('The shape of the FP7 filtered is:',filtered_fp7.shape)
print(' ---- ')
filtered_h2020 = merged_data[merged_data['funding_body'] == 'H2020']
print('The shape of the H2020 filtered is:',filtered_h2020.shape)
print(' ---- ')
filtered_he = merged_data[merged_data['funding_body'] == 'HE']
print('The shape of the HORIZON E filtered is:',filtered_he.shape)
# Out:
# The shape of the FP7 filtered is: (1705, 52)
#  ----
# The shape of the H2020 filtered is: (1728, 52)
#  ----
# The shape of the HORIZON E filtered is: (3, 52)
